# %% [markdown]
# Question-1

# %% [markdown]
# Step 1: Import the necessary libraries

# %%
import pandas as panda
import numpy as nump

# %% [markdown]
# Step 2: Import the dataset from this address.
# Step 3: Assign it to a variable called users

# %%
users=panda.read_table('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',sep='|',index_col='user_id')

# %%
user=panda.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user',delimiter='|')

# %%
user.head(10)
# Out:
#    user_id  age gender     occupation zip_code
# 0        1   24      M     technician    85711
# 1        2   53      F          other    94043
# 2        3   23      M         writer    32067
# 3        4   24      M     technician    43537
# 4        5   33      F          other    15213
# 5        6   42      M      executive    98101
# 6        7   57      M  administrator    91344
# 7        8   36      M  administrator    05201
# 8        9   29      M        student    01002
# 9       10   53      M         lawyer    90703

# %% [markdown]
# Step 4:  Discover what is the mean age per occupation

# %%
MeanAge_Occ=users.groupby('occupation').age.agg(['mean'])

# %%
MeanAge_Occ
# Out:
#                     mean
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %% [markdown]
# Step 5: Discover the Male ratio per occupation and sort it from the most to the least

# %%
totalOcc=users.groupby('gender')['occupation'].value_counts()

# %%
MaleRatio=totalOcc['M']/(totalOcc['F']+totalOcc['M'])

# %%
print(MaleRatio.sort_values(ascending=False))
# Out:
# occupation
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# doctor                NaN
# Name: occupation, dtype: float64

# %% [markdown]
# Step 6. For each occupation, calculate the minimum and maximum ages

# %%
s=users.groupby('occupation').age.agg([min,max])

# %%
s
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %% [markdown]
# Step 7. For each combination of occupation and sex, calculate the mean age

# %%
s1=users.groupby(['occupation','gender'])['age'].mean()

# %%
s1
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %% [markdown]
# Step 8. For each occupation present the percentage of women and men

# %%
MenPercent=MaleRatio*100
WomenPercent=(totalOcc['F']/(totalOcc['M'] + totalOcc['F']))*100
print(WomenPercent)
print(MenPercent)
# Out:
# occupation
# administrator    45.569620
# artist           46.428571
# doctor                 NaN
# educator         27.368421
# engineer          2.985075
# entertainment    11.111111
# executive         9.375000
# healthcare       68.750000
# homemaker        85.714286
# lawyer           16.666667
# librarian        56.862745
# marketing        38.461538
# none             44.444444
# other            34.285714
# programmer        9.090909
# retired           7.142857
# salesman         25.000000
# scientist         9.677419
# student          30.612245
# technician        3.703704
# writer           42.222222
# Name: occupation, dtype: float64
# occupation
# administrator    54.430380
# artist           53.571429
# doctor                 NaN
# educator         72.631579
# engineer         97.014925
# entertainment    88.888889
# executive        90.625000
# healthcare       31.250000
# homemaker        14.285714
# lawyer           83.333333
# librarian        43.137255
# ...

# %% [markdown]
# Question-2

# %% [markdown]
# Step 1: Import the necessary libraries
# Step 2: Import the dataset from this address

# %%
import numpy as nump
import pandas as panda

# %% [markdown]
# Step 3: Assign it to a variable called euro12

# %%
euro12=panda.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')

# %%
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# Step 4: Select only the Goal column

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %% [markdown]
# Step 5: How many team participated in the Euro2012?

# %%
euro12['Team']
# Out:
# 0                 Croatia
# 1          Czech Republic
# 2                 Denmark
# 3                 England
# 4                  France
# 5                 Germany
# 6                  Greece
# 7                   Italy
# 8             Netherlands
# 9                  Poland
# 10               Portugal
# 11    Republic of Ireland
# 12                 Russia
# 13                  Spain
# 14                 Sweden
# 15                Ukraine
# Name: Team, dtype: object

# %% [markdown]
# Step 6: What is the number of columns in the dataset?

# %%
len(euro12.columns)
# Out:
# 35

# %% [markdown]
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them
# to a dataframe called discipline

# %%
discipline=euro12[['Team','Yellow Cards','Red Cards']]
discipline
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8: Sort the teams by Red Cards, then to Yellow Cards

# %%
discipline.sort_values(by=['Red Cards','Yellow Cards',],ascending=False)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %% [markdown]
# Step 9: Calculate the mean Yellow Cards given per Team

# %%
discipline.groupby('Team')['Yellow Cards'].agg(['mean'])
# Out:
#                      mean
# Team
# Croatia               9.0
# Czech Republic        7.0
# Denmark               4.0
# England               5.0
# France                6.0
# Germany               4.0
# Greece                9.0
# Italy                16.0
# Netherlands           5.0
# Poland                7.0
# Portugal             12.0
# Republic of Ireland   6.0
# Russia                6.0
# Spain                11.0
# Sweden                7.0
# Ukraine               5.0

# %% [markdown]
# Step 10: Filter teams that scored more than 6 goals

# %%
euro12[euro12["Goals"].apply(lambda x: x>6)]["Team"]
# Out:
# 5     Germany
# 13      Spain
# Name: Team, dtype: object

# %% [markdown]
# Step 11: Select the teams that start with G

# %%
euro12[euro12["Team"].str.startswith('G')]["Team"]
# Out:
# 5    Germany
# 6     Greece
# Name: Team, dtype: object

# %% [markdown]
# Step 12: Select the first 7 columns

# %%
euro12.iloc[:,:7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 13: Select all columns except the last 3

# %%
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14: Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro12.loc[euro12["Team"].isin(['England', 'Italy', 'Russia']),['Shooting Accuracy']]
# Out:
#    Shooting Accuracy
# 3              50.0%
# 7              43.0%
# 12             22.5%

# %% [markdown]
# Question-3

# %% [markdown]
# Step 1: Import the necessary libraries
# Step 2: Create 3 differents Series, each of length 100, as follows:
# • The first a random number from 1 to 4
# • The second a random number from 1 to 3
# • The third a random number from 10,000 to 30,000

# %%
import pandas as panda
import random
SeriesOne = panda.Series(random.randint(1, 4) for _ in range(100))
SeriesTwo = panda.Series(random.randint(1, 2) for _ in range(100))
SeriesThree = panda.Series(random.randint(10000, 30000) for _ in range(100))
print(SeriesOne)
print(SeriesTwo)
print(SeriesThree)
# Out:
# 0     4
# 1     2
# 2     2
# 3     1
# 4     2
#      ..
# 95    4
# 96    4
# 97    1
# 98    3
# 99    2
# Length: 100, dtype: int64
# 0     1
# 1     1
# 2     1
# 3     1
# 4     2
#      ..
# 95    1
# 96    2
# 97    2
# 98    1
# 99    2
# Length: 100, dtype: int64
# 0     15214
# 1     23570
# 2     25705
# 3     27023
# 4     13419
#       ...
# 95    16597
# 96    14954
# 97    27662
# 98    28206
# 99    12544
# Length: 100, dtype: int64

# %% [markdown]
# Step 3: Create a DataFrame by joinning the Series by column

# %%
df = panda.concat([SeriesOne, SeriesTwo, SeriesThree], axis = 1)
df
# Out:
#     0  1      2
# 0   4  1  15214
# 1   2  1  23570
# 2   2  1  25705
# 3   1  1  27023
# 4   2  2  13419
# .. .. ..    ...
# 95  4  1  16597
# 96  4  2  14954
# 97  1  2  27662
# 98  3  1  28206
# 99  2  2  12544
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4:  Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.columns =["bedrs", "bathrs", "price_sqr_meter"]
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       4       1            15214
# 1       2       1            23570
# 2       2       1            25705
# 3       1       1            27023
# 4       2       2            13419
# ..    ...     ...              ...
# 95      4       1            16597
# 96      4       2            14954
# 97      1       2            27662
# 98      3       1            28206
# 99      2       2            12544
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5: Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'

# %%
bigcolumn=panda.concat([SeriesOne, SeriesTwo, SeriesThree])

# %% [markdown]
# Step 6: Ops it seems it is going only until index 99. Is it true?
# Yes

# %% [markdown]
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
bigcolumn.reset_index()
# Out:
#      index      0
# 0        0      4
# 1        1      2
# 2        2      2
# 3        3      1
# 4        4      2
# ..     ...    ...
# 295     95  16597
# 296     96  14954
# 297     97  27662
# 298     98  28206
# 299     99  12544
#
# [300 rows x 2 columns]

# %% [markdown]
# Question-4

# %% [markdown]
# Step 1- Step 3:

# %%
import pandas as panda
import numpy as nump
import datetime
data = panda.read_csv("https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data", sep="\s+")
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
data["Date"]=panda.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join,axis=1))
data=data.drop(columns=["Yr","Mo","Dy"])
data=data[['Date','RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']]
data.head()
# Out:
#         Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Step 4: Year 2061? Do we really have data from this year? Create a function to fix it
# and apply it.

# %%
data["Date"] = nump.where(panda.DatetimeIndex(data["Date"]).year < 2000,
data.Date,data.Date - panda.offsets.DateOffset(years=100))
data.head()
# Out:
#         Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be
# datetime64[ns].

# %%
data.set_index('Date',inplace=True)

# %% [markdown]
# Step 6. Compute how many values are missing for each location over the entire
# record.They should be ignored in all calculations below.

# %%
s3=data.isnull().sum()
s3
# Out:
# RPT    6
# VAL    3
# ROS    2
# KIL    5
# SHA    2
# BIR    0
# DUB    3
# CLA    2
# MUL    3
# CLO    1
# BEL    0
# MAL    4
# dtype: int64

# %% [markdown]
# Step 7. Compute how many non-missing values there are in total.

# %%
s4=data.notnull().sum().sum()
s4
# Out:
# 78857

# %% [markdown]
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times

# %%
x=data.agg(['mean'])
x.agg(['mean'],axis=1)
# Out:
#            mean
# mean  10.227982

# %% [markdown]
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean
# windspeeds and standard deviations of the windspeeds at each location over all the
# days
# A different set of numbers for each location

# %%
location=panda.DataFrame(data=[data.min(),data.max(),data.mean(),data.std()],index=['mean','max','min','sd'])
location
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# mean   0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# min   12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# sd     5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# mean   0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# min    9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# sd     4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %% [markdown]
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean
# windspeed and standard deviations of the windspeeds across all the locations at each
# day.
# A different set of numbers for each day

# %%
d=data.transpose()
day_stats=pd.DataFrame([d.min(),d.max(),d.mean(),d.std()]).transpose()
day_stats.columns=['mean','max','min','std']
day_stats
# Out:
#             mean    max        min       std
# Date
# 1961-01-01  9.29  18.50  13.018182  2.808875
# 1961-01-02  6.50  17.54  11.336364  3.188994
# 1961-01-03  6.17  18.50  11.641818  3.681912
# 1961-01-04  1.79  11.75   6.619167  3.198126
# 1961-01-05  6.17  13.33  10.630000  2.445356
# ...          ...    ...        ...       ...
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483
#
# [6574 rows x 4 columns]

# %% [markdown]
# Step 11:. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January.

# %%
d=data.reset_index()
d["Date"]=d["Date"].apply(panda.to_datetime)
d.set_index("Date",inplace=True)
d[d.index.month == 1].agg(['mean'])
# Out:
#             RPT       VAL        ROS       KIL        SHA       BIR  \
# mean  14.847325  12.91456  13.299624  7.199498  11.667734  8.054839
#
#             DUB       CLA       MUL        CLO       BEL        MAL
# mean  11.819355  9.512047  9.543208  10.053566  14.55052  18.028763

# %% [markdown]
# Step 12: Downsample the record to a yearly frequency for each location.

# %%
d.resample('Y').agg(['mean'])
# Out:
#                   RPT        VAL        ROS       KIL        SHA       BIR  \
#                  mean       mean       mean      mean       mean      mean
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# ...

# %% [markdown]
# Step 13: Downsample the record to a monthly frequency for each location.

# %%
d.resample('M').agg(['mean'])
# Out:
#                   RPT        VAL        ROS       KIL        SHA        BIR  \
#                  mean       mean       mean      mean       mean       mean
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# ...

# %% [markdown]
# Step 14: Downsample the record to a weekly frequency for each location.

# %%
d.resample('W').agg(['mean'])
# Out:
#                   RPT        VAL        ROS        KIL        SHA        BIR  \
#                  mean       mean       mean       mean       mean       mean
# Date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# ...

# %% [markdown]
# Step 15: Calculate the min, max and mean windspeeds and standard deviations of the
# windspeeds across all locations for each week (assume that the first week starts on B
# January 2 1961) for the first 52 weeks

# %%
d[d.index.year == 1961].resample('W').mean().apply(lambda x: x.describe())
# Out:
#              RPT        VAL        ROS        KIL        SHA        BIR  \
# count  53.000000  53.000000  53.000000  53.000000  52.000000  53.000000
# mean   12.341033  10.419380  11.381716   6.990952  10.876502   7.764340
# std     3.390879   2.874840   2.830804   2.072540   2.677186   2.426115
# min     4.202857   4.255714   6.738571   3.300000   6.112857   2.715714
# 25%    10.236667   8.445714   9.104286   5.478571   8.966071   6.017143
# 50%    11.715714   9.734286  10.875714   6.578571  10.357143   7.492857
# 75%    15.130000  12.951429  13.170000   8.370000  13.277857   9.238571
# max    19.880000  16.417143  18.225714  12.720000  17.432857  14.828571
#
#              DUB        CLA        MUL        CLO        BEL        MAL
# count  53.000000  53.000000  53.000000  53.000000  53.000000  53.000000
# mean    9.805135   8.869915   8.694681   9.872951  13.583612  13.707255
# std     2.837580   2.440596   2.404598   2.588429   3.646558   3.551007
# ...

# %% [markdown]
# Question 5

# %% [markdown]
# Step 1: Import the necessary libraries
# Step 2: Import the dataset from this address.
# Step 3: Assign it to a variable called chipo.
# Step 4: See the first 10 entries

# %%
import pandas as panda
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(url, sep='\t')
chipo[:10]
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %% [markdown]
# Step 5: What is the number of observations in the dataset?

# %%
chipo.shape[0]
# Out:
# 4622

# %% [markdown]
# Step 6: What is the number of columns in the dataset?

# %%
chipo.shape[1]
# Out:
# 5

# %% [markdown]
# Step 7. Print the name of all the columns

# %%
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %% [markdown]
# Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %% [markdown]
# Step 9: Which was the most-ordered item?

# %%
chipo.item_name.value_counts().head(1)
# Out:
# Chicken Bowl    726
# Name: item_name, dtype: int64

# %% [markdown]
# Step 10: For the most-ordered item, how many items were ordered?

# %%
chipo.item_name.unique().shape[0]
# Out:
# 50

# %% [markdown]
# Step 11: What was the most ordered item in the choice_description column?

# %%
chipo.choice_description.value_counts().head()
# Out:
# [Diet Coke]                                                                          134
# [Coke]                                                                               123
# [Sprite]                                                                              77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]     40
# Name: choice_description, dtype: int64

# %% [markdown]
# Step 12: How many items were orderd in total?

# %%
chipo.quantity.sum()
# Out:
# 4972

# %% [markdown]
# Step 13:
# • Turn the item price into a float
# • Check the item price type
# • Create a lambda function and change the type of item price
# • Check the item price type

# %%
chipo.item_price.dtype
# Out:
# dtype('O')

# %% [markdown]
# lambda function:
# df = pd.DataFrame(map(lambda x: pd.to_numeric(chipo["item_price"], errors='coerce'), x) for x in chipo.columns)

# %% [markdown]
# Step 14: How much was the revenue for the period in the dataset?

# %%
chipo.item_price.sum()
# Out:
# '$2.39 $3.39 $3.39 $2.39 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $1.69 $17.50 $4.45 $8.49 $2.39 $17.50 $4.45 $4.45 $11.25 $11.75 $10.98 $
# ...

# %% [markdown]
# Step 15: How many orders were made in the period?

# %%
chipo.order_id.value_counts().count()
# Out:
# 1834

# %% [markdown]
# Step 16: What is the average revenue amount per order?

# %%
r=(chipo["item_price"]*chipo["quantity"]).sum()
r
o=len(chipo["order_id"].unique())
r.sum()/0

# %% [markdown]
# Step 17. How many different items are sold?

# %%
len(chipo["item_name"].unique())
# Out:
# 50

# %% [markdown]
# Question-6

# %%
import pandas as panda
import matplotlib.pyplot as plt
# %matplotlib inline
details = panda.read_csv("us-marriages-divorces-1867-2014.csv")
margs_p_capita = details['Marriages_per_1000']
divrs_p_capita = details['Divorces_per_1000']
columns = margs_p_capita, divrs_p_capita
years = details['Year']
ind = ["margs_p_capita", "divrs_p_capita"]
x_details = range(1867, 1867 + details.shape[0])
fig, axis = plt.subplots()
for i in range(len(columns)):
    axis.plot(x_details, columns[i], label=ind[i])    
axis.set_xlabel('Year')
axis.set_ylabel('The number of Marriages and Divorces')
axis.legend()

# %% [markdown]
# Question-7

# %%
actor=panda.read_csv("us-marriages-divorces-1867-2014.csv")
details[(details['Year'].isin([1900,1950,2000]))].plot.bar(x='Year',y=['Marriages_per_1000','Divorces_per_1000'],xlabel='Year',ylabel='Marriages & Divorcers per capita')
# Out:
# <AxesSubplot:xlabel='Year', ylabel='Marriages & Divorcers per capita'>

# %% [markdown]
# Question-8

# %%
actor_kills_data = pd.read_csv('actor_kill_counts.csv')
kills = actor_kills_data.sort_values(by=['Count'])
Actorname = kills['Actor'].values
Kills_numb = kills['Count'].values
plt.bar(Actorname, Kills_numb, label=Actorname)
plt.xticks(rotation='vertical')
plt.xlabel("Name of actors")
plt.ylabel("Total amount of kills")
# Out:
# Text(0, 0.5, 'Total amount of kills')

# %% [markdown]
# Question-9

# %%
emp=pd.read_csv('roman-emperor-reigns.csv')
emp[(emp['Cause_of_Death']=='Assassinated')].set_index('Emperor').plot(kind='pie',x='Emperor',y='Length_of_Reign',figsize=(8,8),autopct='%1.1f%%').legend(bbox_to_anchor=(1.5,1))

# %% [markdown]
# Question-10

# %%
import seaborn as sns
comp=panda.read_csv('arcade-revenue-vs-cs-doctorates.csv')
sns.lmplot('Total Arcade Revenue (billions)', 'Computer Science Doctorates Awarded (US)', data=comp, hue='Year', fit_reg=False)
# Out:
# C:\Users\heman\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# !pip install seaborn
# Out:
# ...
#      -------------------------------------- 292.8/292.8 kB 4.5 MB/s eta 0:00:00
# ...
